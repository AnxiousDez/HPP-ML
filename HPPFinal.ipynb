# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
data = pd.read_csv("/content/drive/MyDrive/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x=data.drop(['median_house_value'],axis =1)
y=data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12254    -116.99     33.77                 7.0      10352.0          2007.0
# 17279    -119.75     34.40                31.0       1997.0           299.0
# 16155    -122.49     37.78                47.0       2695.0           643.0
# 14561    -117.22     32.83                17.0       1124.0           187.0
# 12452    -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 652      -122.13     37.71                44.0       1613.0           339.0
# 4262     -118.33     34.10                30.0       5293.0          2446.0
# 10672    -117.85     33.61                14.0       4340.0           741.0
# 9841     -121.90     36.60                39.0       1629.0           423.0
# 19379    -120.87     37.77                 9.0       4838.0           920.0
#
#        population  households  median_income ocean_proximity
# 12254      3559.0      1689.0         2.2925          INLAND
# 17279       826.0       301.0         6.8927      NEAR OCEAN
# 16155      1505.0       644.0         3.0877        NEAR BAY
# 14561       553.0       205.0         5.7451      NEAR OCEAN
# 12452       624.0       262.0         1.9250          INLAND
# ...           ...         ...            ...             ...
# 652         776.0       346.0         3.1103        NEAR BAY
# 4262       4123.0      2127.0         1.5100       <1H OCEAN
# 10672      1505.0       670.0         7.5674       <1H OCEAN
# 9841        804.0       386.0         2.4663      NEAR OCEAN
# 19379      2460.0       923.0         3.5959          INLAND
#
# [16346 rows x 9 columns]

# %%
y_train
# Out:
# 12254    113100.0
# 17279    500001.0
# 16155    329100.0
# 14561    237300.0
# 12452     65500.0
#            ...
# 652      188900.0
# 4262     187500.0
# 10672    500001.0
# 9841     236500.0
# 19379    142700.0
# Name: median_house_value, Length: 16346, dtype: float64

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12254    -116.99     33.77                 7.0      10352.0          2007.0
# 17279    -119.75     34.40                31.0       1997.0           299.0
# 16155    -122.49     37.78                47.0       2695.0           643.0
# 14561    -117.22     32.83                17.0       1124.0           187.0
# 12452    -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 652      -122.13     37.71                44.0       1613.0           339.0
# 4262     -118.33     34.10                30.0       5293.0          2446.0
# 10672    -117.85     33.61                14.0       4340.0           741.0
# 9841     -121.90     36.60                39.0       1629.0           423.0
# 19379    -120.87     37.77                 9.0       4838.0           920.0
#
#        population  households  median_income ocean_proximity  \
# 12254      3559.0      1689.0         2.2925          INLAND
# 17279       826.0       301.0         6.8927      NEAR OCEAN
# 16155      1505.0       644.0         3.0877        NEAR BAY
# 14561       553.0       205.0         5.7451      NEAR OCEAN
# 12452       624.0       262.0         1.9250          INLAND
# ...           ...         ...            ...             ...
# 652         776.0       346.0         3.1103        NEAR BAY
# 4262       4123.0      2127.0         1.5100       <1H OCEAN
# 10672      1505.0       670.0         7.5674       <1H OCEAN
# 9841        804.0       386.0         2.4663      NEAR OCEAN
# 19379      2460.0       923.0         3.5959          INLAND
#
#        median_house_value
# 12254            113100.0
# 17279            500001.0
# 16155            329100.0
# 14561            237300.0
# 12452             65500.0
# ...                   ...
# 652              188900.0
# 4262             187500.0
# 10672            500001.0
# 9841             236500.0
# 19379            142700.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
#
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12254    8.177516    7.432484         2.2925            113100.0          0
# 17279    6.717805    5.710427         6.8927            500001.0          0
# 16155    7.317212    6.469250         3.0877            329100.0          0
# 14561    6.317165    5.327876         5.7451            237300.0          0
# 12452    6.437752    5.572154         1.9250             65500.0          0
# ...           ...         ...            ...                 ...        ...
# 652      6.655440    5.849325         3.1103            188900.0          0
# 4262     8.324579    7.662938         1.5100            187500.0          1
# 10672    7.317212    6.508769         7.5674            500001.0          1
# 9841     6.690842    5.958425         2.4663            236500.0          0
# 19379    7.808323    6.828712         3.5959            142700.0          0
#
#        INLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 12254       1         0           0       0.822593         1.243868
# 17279       0         0           1       0.750507         1.330882
# 16155       0         1           0       0.818745         1.221088
# 14561       0         0           1       0.745344         1.318638
# 12452       1         0           0       0.795023         1.306992
# ...       ...       ...         ...            ...              ...
# 652         0         1           0       0.789138         1.262790
# 4262        0         0           0       0.909997         1.118935
# 10672       0         0           0       0.789095         1.286858
# 9841        0         0           1       0.817937         1.241324
# 19379       1         0           0       0.804466         1.242469
#
# [16346 rows x 15 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler =StandardScaler()

x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

x_train_s = scaler.fit_transform(x_train)


reg=LinearRegression()

reg.fit(x_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# Calculate the missing columns for test_data
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
x_test_s = scaler.transform(x_test)

# %%
reg.score(x_test_s,y_test)
# Out:
# 0.3489639151403966

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train_s,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s,y_test)
# Out:
# 0.4055522988451502

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid={
    "n_estimators":[5,10,30],
    "min_samples_split":[2,4,6,8],
}

grid_search1 = GridSearchCV(forest, param_grid, cv=5,
                           scoring = "neg_mean_squared_error",
                           return_train_score=True)

grid_search1.fit(x_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [5, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search1.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=6, n_estimators=30)

# %%
grid_search1.best_estimator_.score(x_test_s,y_test)
# Out:
# 0.4064401422935342

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid={
    "n_estimators":[100, 200, 300],
    "min_samples_split":[2,4],
    "max_depth":[None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring = "neg_mean_squared_error",
                           return_train_score=True)

grid_search.fit(x_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=4, n_estimators=300)

# %%
grid_search.best_estimator_.score(x_test_s,y_test)
# Out:
# 0.42471343450566623

# %%
import os

# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Out:
# /content

# %%
import pickle
with open('model1.pkl', 'wb') as file:
    pickle.dump(grid_search1, file)

# %%
import pickle
with open('model2.pkl', 'wb') as file:
    pickle.dump(grid_search, file)
